# %%
import pandas as pd

# %%
data =  pd.read_csv("DATA\\Neighborhood_zhvi_bdrmcnt_2_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")

# %%
city_data = pd.read_csv("DATA\\City_zhvi_bdrmcnt_2_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")

# %%
data.head()
# Out:
#    RegionID  SizeRank         RegionName    RegionType StateName State  \
# 0    112345         0           Maryvale  neighborhood        AZ    AZ
# 1    192689         1           Paradise  neighborhood        NV    NV
# 2    270958         2    Upper West Side  neighborhood        NY    NY
# 3    270957         3    Upper East Side  neighborhood        NY    NY
# 4    118208         4  South Los Angeles  neighborhood        CA    CA
#
#           City                                  Metro          CountyName  \
# 0      Phoenix              Phoenix-Mesa-Chandler, AZ     Maricopa County
# 1    Las Vegas       Las Vegas-Henderson-Paradise, NV        Clark County
# 2     New York  New York-Newark-Jersey City, NY-NJ-PA     New York County
# 3     New York  New York-Newark-Jersey City, NY-NJ-PA     New York County
# 4  Los Angeles     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County
#
#       2000-01-31  ...    2023-02-28    2023-03-31    2023-04-30    2023-05-31  \
# ...

# %%
data['City'].unique()
# Out:
# array(['Phoenix', 'Las Vegas', 'New York', 'Los Angeles', 'Fresno',
#        'El Paso', 'Corpus Christi', 'Houston', 'San Jose', 'Boston',
#        'Memphis', 'Chicago', 'Arlington', 'Long Beach', 'Orlando',
#        'Miami', 'Raleigh', 'Naples', 'Santa Clarita', 'San Diego',
#        'Anaheim', 'Chula Vista', 'Colorado Springs', 'Virginia Beach',
#        'Louisville', 'Sacramento', 'Whittier', 'Philadelphia',
#        'Jersey City', 'Tucson', 'Concord', 'Beaverton', 'San Francisco',
#        'Woodbridge', 'Newark', 'Evesham Township', 'Thousand Oaks',
#        'Denver', 'Tacoma', 'Newport News', 'Henderson', 'Kansas City',
#        'Indianapolis', 'Alexandria', 'Riverside', 'Seattle', 'Eastvale',
#        'Albuquerque', 'North Miami', 'Homestead', 'Boise', 'Kissimmee',
#        'Omaha', 'Washington', 'Jurupa Valley', 'New Orleans',
#        'Saint Johns', 'Cincinnati', 'Pasadena', 'Salt Lake City',
#        'Cleveland', 'Saint Paul', 'Fairfax', 'Pittsburgh', 'McKinney',
# ...

# %%
lasVegas_data = data[data['City'] == 'Las Vegas']

# %%
lasVegas_data.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'City', 'Metro', 'CountyName', '2000-01-31',
#        ...
#        '2023-02-28', '2023-03-31', '2023-04-30', '2023-05-31', '2023-06-30',
#        '2023-07-31', '2023-08-31', '2023-09-30', '2023-10-31', '2023-11-30'],
#       dtype='object', length=296)

# %%
lasVegas_data
# Out:
#       RegionID  SizeRank                 RegionName    RegionType StateName  \
# 1       192689         1                   Paradise  neighborhood        NV
# 5       192796         5              Spring Valley  neighborhood        NV
# 9       192820         9              Sunrise Manor  neighborhood        NV
# 16       35521        16                 Enterprise  neighborhood        NV
# 86      273177        87           Centennial Hills  neighborhood        NV
# 144     274346       151              Lone Mountain  neighborhood        NV
# 148     275609       155            Summerlin North  neighborhood        NV
# 170     274510       180                Michael Way  neighborhood        NV
# 252     274697       272             North Cheyenne  neighborhood        NV
# 287     276253       311         Charleston Heights  neighborhood        NV
# 289     396209       313            Summerlin South  neighborhood        NV
# ...

# %%
transposed_lasVegas_data = lasVegas_data.T

# %%
transposed_lasVegas_data.columns
# Out:
# Index([   1,    5,    9,   16,   86,  144,  148,  170,  252,  287,  289,  291,
#         306,  369,  428,  481,  537,  627,  646,  757,  817,  881,  905,  943,
#        1012, 1097, 1327, 1407, 1478, 2252, 4275, 4953, 5256],
#       dtype='int64')

# %%
transposed_lasVegas_data.head(10)
# Out:
#                                         1     \
# RegionID                              192689
# SizeRank                                   1
# RegionName                          Paradise
# RegionType                      neighborhood
# StateName                                 NV
# State                                     NV
# City                               Las Vegas
# Metro       Las Vegas-Henderson-Paradise, NV
# CountyName                      Clark County
# 2000-01-31                      96725.470437
#
#                                         5     \
# RegionID                              192796
# SizeRank                                   5
# RegionName                     Spring Valley
# RegionType                      neighborhood
# StateName                                 NV
# State                                     NV
# City                               Las Vegas
# Metro       Las Vegas-Henderson-Paradise, NV
# CountyName                      Clark County
# ...

# %%
transposed_lasVegas_data.loc["RegionName", 23:]
# Out:
# 86               Centennial Hills
# 144                 Lone Mountain
# 148               Summerlin North
# 170                   Michael Way
# 252                North Cheyenne
# 287            Charleston Heights
# 289               Summerlin South
# 291                       Whitney
# 306             Rancho Charleston
# 369                East Las Vegas
# 428                     The Lakes
# 481                    Winchester
# 537                Sheep Mountain
# 627                West Las Vegas
# 646                  Tule Springs
# 757                       Sunrise
# 817                       Buffalo
# 881                     Huntridge
# 905                  Pioneer Park
# 943                 Desert Shores
# 1012            Cultural Corridor
# 1097           Angel Park Lindell
# 1327                     Downtown
# 1407                   Twin Lakes
# 1478           Sun City Summerlin
# 2252                Downtown East
# 4275    University Medical Center
# ...

# %%
transposed_lasVegas_data.columns
# Out:
# Index([   1,    5,    9,   16,   86,  144,  148,  170,  252,  287,  289,  291,
#         306,  369,  428,  481,  537,  627,  646,  757,  817,  881,  905,  943,
#        1012, 1097, 1327, 1407, 1478, 2252, 4275, 4953, 5256],
#       dtype='int64')

# %%
# transposed_lasVegas_data.loc["RegionName", :]

# assign regionname as the columns

transposed_lasVegas_data.columns = transposed_lasVegas_data.loc["RegionName", :]

# %%
transposed_lasVegas_data.columns
# Out:
# Index(['Paradise', 'Spring Valley', 'Sunrise Manor', 'Enterprise',
#        'Centennial Hills', 'Lone Mountain', 'Summerlin North', 'Michael Way',
#        'North Cheyenne', 'Charleston Heights', 'Summerlin South', 'Whitney',
#        'Rancho Charleston', 'East Las Vegas', 'The Lakes', 'Winchester',
#        'Sheep Mountain', 'West Las Vegas', 'Tule Springs', 'Sunrise',
#        'Buffalo', 'Huntridge', 'Pioneer Park', 'Desert Shores',
#        'Cultural Corridor', 'Angel Park Lindell', 'Downtown', 'Twin Lakes',
#        'Sun City Summerlin', 'Downtown East', 'University Medical Center',
#        'The Strip', 'Queensridge'],
#       dtype='object', name='RegionName')

# %%
transposed_lasVegas_data
# Out:
# RegionName       Paradise  Spring Valley  Sunrise Manor     Enterprise  \
# RegionID           192689         192796         192820          35521
# SizeRank                1              5              9             16
# RegionName       Paradise  Spring Valley  Sunrise Manor     Enterprise
# RegionType   neighborhood   neighborhood   neighborhood   neighborhood
# StateName              NV             NV             NV             NV
# ...                   ...            ...            ...            ...
# 2023-07-31  250130.661511  249969.082955  218514.669384  311934.604617
# 2023-08-31   251956.01742  251499.427304  219911.393508  312978.346471
# 2023-09-30  253806.228191  253202.706217  221358.567852  314087.347873
# 2023-10-31  255456.372671  254726.869174  222637.110046  315043.398656
# 2023-11-30  256800.876163  255978.236545   223785.64203  316108.017312
#
# RegionName  Centennial Hills  Lone Mountain  Summerlin North    Michael Way  \
# ...

# %%
transposed_lasVegas_data.head(10)
# Out:
# RegionName                          Paradise  \
# RegionID                              192689
# SizeRank                                   1
# RegionName                          Paradise
# RegionType                      neighborhood
# StateName                                 NV
# State                                     NV
# City                               Las Vegas
# Metro       Las Vegas-Henderson-Paradise, NV
# CountyName                      Clark County
# 2000-01-31                      96725.470437
#
# RegionName                     Spring Valley  \
# RegionID                              192796
# SizeRank                                   5
# RegionName                     Spring Valley
# RegionType                      neighborhood
# StateName                                 NV
# State                                     NV
# City                               Las Vegas
# Metro       Las Vegas-Henderson-Paradise, NV
# CountyName                      Clark County
# ...

# %%
transposed_lasVegas_data.index[list(range(9))]
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'City', 'Metro', 'CountyName'],
#       dtype='object')

# %%
transposed_lasVegas_data.drop(transposed_lasVegas_data.index[list(range(9))], inplace=True)

# %%
transposed_lasVegas_data
# Out:
# RegionName       Paradise  Spring Valley  Sunrise Manor     Enterprise  \
# 2000-01-31   96725.470437  105675.531451    89398.32904  127209.031373
# 2000-02-29    96638.14658  105645.915338   89373.746067  127174.750471
# 2000-03-31   96689.066626   105752.48517   89486.096085  127199.303181
# 2000-04-30   96876.417057  106068.100685   89798.401768    127233.2882
# 2000-05-31   97122.885932  106504.196964   90231.017714  127169.701372
# ...                   ...            ...            ...            ...
# 2023-07-31  250130.661511  249969.082955  218514.669384  311934.604617
# 2023-08-31   251956.01742  251499.427304  219911.393508  312978.346471
# 2023-09-30  253806.228191  253202.706217  221358.567852  314087.347873
# 2023-10-31  255456.372671  254726.869174  222637.110046  315043.398656
# 2023-11-30  256800.876163  255978.236545   223785.64203  316108.017312
#
# RegionName Centennial Hills  Lone Mountain Summerlin North    Michael Way  \
# ...

# %%
transposed_lasVegas_data.index
# Out:
# Index(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-30', '2000-05-31',
#        '2000-06-30', '2000-07-31', '2000-08-31', '2000-09-30', '2000-10-31',
#        ...
#        '2023-02-28', '2023-03-31', '2023-04-30', '2023-05-31', '2023-06-30',
#        '2023-07-31', '2023-08-31', '2023-09-30', '2023-10-31', '2023-11-30'],
#       dtype='object', length=287)

# %%
transposed_lasVegas_data.index.rename('Date', inplace=True)

# %%
transposed_lasVegas_data
# Out:
# RegionName       Paradise  Spring Valley  Sunrise Manor     Enterprise  \
# Date
# 2000-01-31   96725.470437  105675.531451    89398.32904  127209.031373
# 2000-02-29    96638.14658  105645.915338   89373.746067  127174.750471
# 2000-03-31   96689.066626   105752.48517   89486.096085  127199.303181
# 2000-04-30   96876.417057  106068.100685   89798.401768    127233.2882
# 2000-05-31   97122.885932  106504.196964   90231.017714  127169.701372
# ...                   ...            ...            ...            ...
# 2023-07-31  250130.661511  249969.082955  218514.669384  311934.604617
# 2023-08-31   251956.01742  251499.427304  219911.393508  312978.346471
# 2023-09-30  253806.228191  253202.706217  221358.567852  314087.347873
# 2023-10-31  255456.372671  254726.869174  222637.110046  315043.398656
# 2023-11-30  256800.876163  255978.236545   223785.64203  316108.017312
#
# RegionName Centennial Hills  Lone Mountain Summerlin North    Michael Way  \
# Date
# ...

# %%
# add a new column 'average' with the average of each row
transposed_lasVegas_data['average'] = transposed_lasVegas_data.mean(axis=1)

# %%
transposed_lasVegas_data
# Out:
# RegionName       Paradise  Spring Valley  Sunrise Manor     Enterprise  \
# Date
# 2000-01-31   96725.470437  105675.531451    89398.32904  127209.031373
# 2000-02-29    96638.14658  105645.915338   89373.746067  127174.750471
# 2000-03-31   96689.066626   105752.48517   89486.096085  127199.303181
# 2000-04-30   96876.417057  106068.100685   89798.401768    127233.2882
# 2000-05-31   97122.885932  106504.196964   90231.017714  127169.701372
# ...                   ...            ...            ...            ...
# 2023-07-31  250130.661511  249969.082955  218514.669384  311934.604617
# 2023-08-31   251956.01742  251499.427304  219911.393508  312978.346471
# 2023-09-30  253806.228191  253202.706217  221358.567852  314087.347873
# 2023-10-31  255456.372671  254726.869174  222637.110046  315043.398656
# 2023-11-30  256800.876163  255978.236545   223785.64203  316108.017312
#
# RegionName Centennial Hills  Lone Mountain Summerlin North    Michael Way  \
# Date
# ...

# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 10))

# plot the time series
transposed_lasVegas_data['average'].plot()

# add title and axis labels to plot
plt.title('Time Series Plot')
plt.xlabel('Date')
plt.ylabel('average')

plt.show()

# %%
transposed_lasVegas_data.columns
# Out:
# Index(['Paradise', 'Spring Valley', 'Sunrise Manor', 'Enterprise',
#        'Centennial Hills', 'Lone Mountain', 'Summerlin North', 'Michael Way',
#        'North Cheyenne', 'Charleston Heights', 'Summerlin South', 'Whitney',
#        'Rancho Charleston', 'East Las Vegas', 'The Lakes', 'Winchester',
#        'Sheep Mountain', 'West Las Vegas', 'Tule Springs', 'Sunrise',
#        'Buffalo', 'Huntridge', 'Pioneer Park', 'Desert Shores',
#        'Cultural Corridor', 'Angel Park Lindell', 'Downtown', 'Twin Lakes',
#        'Sun City Summerlin', 'Downtown East', 'University Medical Center',
#        'The Strip', 'Queensridge', 'average'],
#       dtype='object', name='RegionName')

# %%
plt.figure(figsize=(15, 10))

# plot the time series
transposed_lasVegas_data['average'].plot(label='Average')
transposed_lasVegas_data['The Strip'].plot(label='The Strip')  
transposed_lasVegas_data['Queensridge'].plot(label='Queensridge')
transposed_lasVegas_data['Summerlin South'].plot(label='Summerlin South')
transposed_lasVegas_data['Downtown'].plot(label='Downtown')
transposed_lasVegas_data['Sunrise Manor'].plot(label='Sunrise Manor')
transposed_lasVegas_data['West Las Vegas'].plot(label='West Las Vegas')
transposed_lasVegas_data['Buffalo'].plot(label='Buffalo')
transposed_lasVegas_data['East Las Vegas'].plot(label='East Las Vegas')
transposed_lasVegas_data['Cultural Corridor'].plot(label='Cultural Corridor')

# add title and axis labels to plot
plt.title('Top Five and Bottom Five')
plt.xlabel('Date')
plt.ylabel('Average')
plt.legend()

plt.show()

# %%
transposed_lasVegas_data.index
# Out:
# Index(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-30', '2000-05-31',
#        '2000-06-30', '2000-07-31', '2000-08-31', '2000-09-30', '2000-10-31',
#        ...
#        '2023-02-28', '2023-03-31', '2023-04-30', '2023-05-31', '2023-06-30',
#        '2023-07-31', '2023-08-31', '2023-09-30', '2023-10-31', '2023-11-30'],
#       dtype='object', name='Date', length=287)

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
train = transposed_lasVegas_data.loc[transposed_lasVegas_data.index < '2018-01-31']
test = transposed_lasVegas_data.loc[transposed_lasVegas_data.index >= '2018-01-31']

# %%
transposed_lasVegas_data.isna().sum()
# Out:
# RegionName
# Paradise                       0
# Spring Valley                  0
# Sunrise Manor                  0
# Enterprise                     0
# Centennial Hills               0
# Lone Mountain                  0
# Summerlin North                0
# Michael Way                    0
# North Cheyenne                 0
# Charleston Heights             0
# Summerlin South               60
# Whitney                        0
# Rancho Charleston              0
# East Las Vegas                 0
# The Lakes                      1
# Winchester                     0
# Sheep Mountain                96
# West Las Vegas                 0
# Tule Springs                 104
# Sunrise                        0
# Buffalo                        1
# Huntridge                      0
# Pioneer Park                   2
# Desert Shores                  1
# Cultural Corridor              0
# Angel Park Lindell             0
# Downtown                       1
# Twin Lakes                   162
# ...

# %%
transposed_lasVegas_data.columns
# Out:
# Index(['Paradise', 'Spring Valley', 'Sunrise Manor', 'Enterprise',
#        'Centennial Hills', 'Lone Mountain', 'Summerlin North', 'Michael Way',
#        'North Cheyenne', 'Charleston Heights', 'Summerlin South', 'Whitney',
#        'Rancho Charleston', 'East Las Vegas', 'The Lakes', 'Winchester',
#        'Sheep Mountain', 'West Las Vegas', 'Tule Springs', 'Sunrise',
#        'Buffalo', 'Huntridge', 'Pioneer Park', 'Desert Shores',
#        'Cultural Corridor', 'Angel Park Lindell', 'Downtown', 'Twin Lakes',
#        'Sun City Summerlin', 'Downtown East', 'University Medical Center',
#        'The Strip', 'Queensridge', 'average'],
#       dtype='object', name='RegionName')

# %%
# features and labels
features = ['Paradise', 'Spring Valley', 'Sunrise Manor', 'Enterprise',
       'Centennial Hills', 'Lone Mountain', 'Michael Way',
       'North Cheyenne', 'Charleston Heights']
label = 'average'

# %%
# slicing
X_train  = train[features]
y_train = train[label]


X_test = test[features]
y_test  = test[label]

# %%
X_test
# Out:
# RegionName       Paradise  Spring Valley  Sunrise Manor     Enterprise  \
# Date
# 2018-01-31  145875.007777  154250.799909  114582.479072  198800.569593
# 2018-02-28  148453.485162  156946.033328  117444.845413  201330.214533
# 2018-03-31  151045.631053   159623.76775  120583.009567  203872.383925
# 2018-04-30   153634.91508  162178.473499  123891.665436  206390.534064
# 2018-05-31  156215.751304  164635.189114  127295.404081  209011.647906
# ...                   ...            ...            ...            ...
# 2023-07-31  250130.661511  249969.082955  218514.669384  311934.604617
# 2023-08-31   251956.01742  251499.427304  219911.393508  312978.346471
# 2023-09-30  253806.228191  253202.706217  221358.567852  314087.347873
# 2023-10-31  255456.372671  254726.869174  222637.110046  315043.398656
# 2023-11-30  256800.876163  255978.236545   223785.64203  316108.017312
#
# RegionName Centennial Hills  Lone Mountain    Michael Way North Cheyenne  \
# Date
# ...

# %%
linear_model = LinearRegression()   # initialize the model

# %%
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = linear_model.predict(X_test)

# %%
pred
# Out:
# array([176710.39936023, 179334.02759664, 181698.6207383 , 183813.69872138,
#        186132.89371213, 188445.72985647, 191413.31553045, 194490.24851591,
#        197687.92081362, 200466.75826472, 202625.46954133, 203678.96259626,
#        204062.47781618, 204708.01722204, 205605.7856709 , 206885.48148831,
#        207755.87495787, 208911.51422954, 209673.60217898, 210524.28910057,
#        210942.54961526, 211422.35841449, 211592.65489383, 211847.57501338,
#        212763.67101146, 214520.02777138, 216457.95574096, 218277.87898192,
#        219101.7655127 , 219064.78995019, 218262.07981559, 217386.09203033,
#        217186.7249413 , 217275.93242151, 218380.31926808, 220327.29900157,
#        222628.38628414, 224963.99519637, 227634.73844303, 230400.94024861,
#        233814.25722215, 237802.64172777, 242760.74344106, 247650.99941563,
#        252033.30128781, 255549.17463819, 258705.94959571, 261697.70611416,
# ...

# %%
df_predict = pd.DataFrame(pred)

# %%
df_predict.rename(columns = {0:"predicted_values"}, inplace=True)

# %%
y_test.values
# Out:
# array([178916.98626974458, 181561.52628687606, 184424.14270049115,
#        187437.13622477237, 190643.07769133008, 193777.30831296075,
#        197328.15470520122, 201008.844774778, 204331.9175078942,
#        206900.60681221084, 208933.27936501626, 210528.19807900378,
#        211735.74020508945, 212730.72591271665, 213256.5970263496,
#        213670.89492443416, 213619.13783217507, 213955.73842969985,
#        214236.17792791064, 214613.61317155344, 214533.22566434284,
#        214380.0611762167, 214387.86092537688, 214687.28470066516,
#        216357.84509438605, 218877.8022167518, 221770.93917119992,
#        223960.91167096404, 224971.54471151312, 224575.77299137073,
#        223140.1518644769, 221725.54473521007, 221238.83648197414,
#        221523.74620152067, 222715.17865323904, 224541.57810028578,
#        226449.1281358143, 228389.7082554511, 230793.76170931317,
#        233862.98647542793, 238062.8929132219, 243581.85117905057,
# ...

# %%
df_predict
# Out:
#     predicted_values
# 0      176710.399360
# 1      179334.027597
# 2      181698.620738
# 3      183813.698721
# 4      186132.893712
# ..               ...
# 66     285349.471274
# 67     287802.392826
# 68     290095.551478
# 69     292120.261328
# 70     293818.353938
#
# [71 rows x 1 columns]

# %%
df_predict["actual_values"] = y_test.values

# %%
df_predict['Date'] = y_test.index

# %%
df_predict.set_index('Date', inplace=True)

# %%
df_predict.index
# Out:
# Index(['2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31',
#        '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31',
#        '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31',
#        '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#        '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31',
#        '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30',
#        '2020-07-31', '2020-08-31', '2020-09-30', '2020-10-31', '2020-11-30',
#        '2020-12-31', '2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#        '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31', '2021-09-30',
#        '2021-10-31', '2021-11-30', '2021-12-31', '2022-01-31', '2022-02-28',
#        '2022-03-31', '2022-04-30', '2022-05-31', '2022-06-30', '2022-07-31',
#        '2022-08-31', '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31',
# ...

# %%
df_predict.index = pd.to_datetime(df_predict.index)

# %%
transposed_lasVegas_data.index = pd.to_datetime(transposed_lasVegas_data.index)

# %%
df_predict
# Out:
#             predicted_values  actual_values
# Date
# 2018-01-31     176710.399360   178916.98627
# 2018-02-28     179334.027597  181561.526287
# 2018-03-31     181698.620738    184424.1427
# 2018-04-30     183813.698721  187437.136225
# 2018-05-31     186132.893712  190643.077691
# ...                      ...            ...
# 2023-07-31     285349.471274  297533.895989
# 2023-08-31     287802.392826  299528.243311
# 2023-09-30     290095.551478  301467.170903
# 2023-10-31     292120.261328  303260.937858
# 2023-11-30     293818.353938  304867.484157
#
# [71 rows x 2 columns]

# %%
plt.figure(figsize=(15, 10))

# plot the time series
df_predict['predicted_values'].plot(label="predicted_values")
df_predict['actual_values'].plot(label="actual_values")

# add title and axis labels to plot
plt.title('predicted vs actual values')
plt.xlabel('Index')
plt.ylabel('Price')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(15, 10))

# plot the time series
transposed_lasVegas_data['average'].plot()

# add title and axis labels to plot
plt.title('predicted vs actual values')
plt.xlabel('Index')
plt.ylabel('Price')
plt.legend()

plt.show()

# %%
predictVactual_data[['predicted_values', 'average']]
# Out:
#             predicted_values        average
# Date
# 2000-01-31               NaN   98397.343826
# 2000-02-29               NaN   98409.038492
# 2000-03-31               NaN   98560.523935
# 2000-04-30               NaN   98899.159527
# 2000-05-31               NaN   99289.104691
# ...                      ...            ...
# 2023-07-31               NaN  297533.895989
# 2023-08-31               NaN  299528.243311
# 2023-09-30               NaN  301467.170903
# 2023-10-31               NaN  303260.937858
# 2023-11-30               NaN  304867.484157
#
# [287 rows x 2 columns]

# %%
# predictVactual_data =transposed_lasVegas_data.merge(df_predict[['predicted_values']], how='left', left_index=True, right_index=True)
# predictVactual_data[['average']].plot(figsize=(15, 5))
# predictVactual_data['predicted_values'].plot(style='.')
# plt.legend(['Actual Data', 'Predictions'])
# plt.title('Actual Data and Prediction')
# plt.show()





plt.figure(figsize=(15, 10))

transposed_lasVegas_data['average'].plot()
df_predict['predicted_values'].plot()

plt.legend(['Actual Data', 'Predictions'])
plt.title('Actual Data and Prediction')
plt.show()
